# %%
import pandas as pd
ies_df = pd.read_csv('IES.csv', sep=';', encoding='latin1')
IGC_df = pd.read_excel('IGC.xlsx')

# %%
ies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2537 entries, 0 to 2536
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    2537 non-null   int64
#  1   CO_IES                        2537 non-null   int64
#  2   NO_IES                        2537 non-null   object
#  3   SG_IES                        2111 non-null   object
#  4   TP_CATEGORIA_ADMINISTRATIVA   2537 non-null   int64
#  5   TP_ORGANIZACAO_ACADEMICA      2537 non-null   int64
#  6   CO_REGIAO                     2537 non-null   int64
#  7   CO_UF                         2537 non-null   int64
#  8   CO_MUNICIPIO                  2537 non-null   int64
#  9   IN_CAPITAL                    2537 non-null   int64
#  10  QT_TEC_TOTAL                  2537 non-null   int64
#  11  QT_TEC_SUPERIOR_FEM           2537 non-null   int64
#  12  QT_TEC_SUPERIOR_MASC          2537 non-null   int64
# ...

# %%
IGC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071 entries, 0 to 2070
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2071 non-null   int64
#  1   CO_IES       2071 non-null   int64
#  2   Graduacao    2052 non-null   float64
#  3   Mestrado     2071 non-null   float64
#  4   Doutorado    2071 non-null   float64
#  5   IGC (Faixa)  2071 non-null   object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 97.2+ KB

# %%
IES_df = ies_df.merge(IGC_df, on='CO_IES')
IES_df = IES_df.drop(['Unnamed: 0_x', 'Unnamed: 0_y'], axis=1)
IES_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2031 entries, 0 to 2030
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CO_IES                        2031 non-null   int64
#  1   NO_IES                        2031 non-null   object
#  2   SG_IES                        1735 non-null   object
#  3   TP_CATEGORIA_ADMINISTRATIVA   2031 non-null   int64
#  4   TP_ORGANIZACAO_ACADEMICA      2031 non-null   int64
#  5   CO_REGIAO                     2031 non-null   int64
#  6   CO_UF                         2031 non-null   int64
#  7   CO_MUNICIPIO                  2031 non-null   int64
#  8   IN_CAPITAL                    2031 non-null   int64
#  9   QT_TEC_TOTAL                  2031 non-null   int64
#  10  QT_TEC_SUPERIOR_FEM           2031 non-null   int64
#  11  QT_TEC_SUPERIOR_MASC          2031 non-null   int64
#  12  QT_TEC_ESPECIALIZACAO_FEM     2031 non-null   int64
# ...

# %%
display(IES_df)
# Out:
#       CO_IES                                             NO_IES   SG_IES  \
# 0          1                UNIVERSIDADE FEDERAL DE MATO GROSSO     UFMT
# 1          2                           UNIVERSIDADE DE BRASÍLIA      UNB
# 2          3                    UNIVERSIDADE FEDERAL DE SERGIPE      UFS
# 3          4                   UNIVERSIDADE FEDERAL DO AMAZONAS     UFAM
# 4          6                 UNIVERSIDADE FEDERAL DE OURO PRETO     UFOP
# ...      ...                                                ...      ...
# 2026   17593                              Faculdade de Botucatu      FDB
# 2027   23410  UNIVERSIDADE ESTADUAL DA REGIÃO TOCANTINA DO M...  UEMASUL
# 2028     284                   FACULDADE DE MEDICINA DE ITAJUBÁ     FMIT
# 2029     633                    INSTITUTO MILITAR DE ENGENHARIA      IME
# 2030      74  FACULDADE DE FILOSOFIA CIÊNCIAS E LETRAS DE SÃ...     FFCL
#
#       TP_CATEGORIA_ADMINISTRATIVA  TP_ORGANIZACAO_ACADEMICA  CO_REGIAO  CO_UF  \
# ...

# %%
IES_df.to_csv(r'C:\Users\jaff_\Google Drive\_Dissertação\Dados Dissertação\Python\IESs_IGC.csv', sep=';', encoding='latin1')

# %%
#informações gerais sobre as IESs

ies_cat = IES_df['TP_CATEGORIA_ADMINISTRATIVA'].value_counts()
display(ies_cat)

ies_org = IES_df['TP_ORGANIZACAO_ACADEMICA'].value_counts()
display(ies_org)

ies_reg = IES_df['CO_REGIAO'].value_counts()
display(ies_reg)

ies_UF = IES_df['CO_UF'].value_counts()
display(ies_UF)

ies_capital = IES_df['IN_CAPITAL'].value_counts()
display(ies_capital)
# Out:
# 4    1303
# 5     935
# 2     128
# 1     110
# 3      36
# 7      25
# Name: TP_CATEGORIA_ADMINISTRATIVA, dtype: int64
# 3    2068
# 2     230
# 1     199
# 4      38
# 5       2
# Name: TP_ORGANIZACAO_ACADEMICA, dtype: int64
# 3    1126
# 2     566
# 4     414
# 5     258
# 1     173
# Name: CO_REGIAO, dtype: int64
# 35    612
# 31    301
# 41    196
# 29    146
# 33    136
# 43    121
# 26    117
# 52     98
# 42     97
# 23     83
# 32     77
# 53     66
# 51     61
# 15     57
# 21     53
# 25     45
# 22     45
# 11     35
# 50     33
# 27     29
# 24     29
# 17     24
# 13     23
# 28     19
# 16     15
# 12     11
# 14      8
# Name: CO_UF, dtype: int64
# 0    1633
# 1     904
# Name: IN_CAPITAL, dtype: int64

# %% [markdown]
# ### Medidas de 'qualidade' e acesso a bases científicas

# %%
ies_tec = IES_df[['QT_TEC_TOTAL', 'CO_IES']]
display(ies_tec)
# Out:
#       QT_TEC_TOTAL  CO_IES
# 0             1639       1
# 1             3171       2
# 2             1464       3
# 3             1706       4
# 4              750       6
# ...            ...     ...
# 2532            66   23410
# 2533            59     284
# 2534           297     633
# 2535            16    3311
# 2536            20      74
#
# [2537 rows x 2 columns]

# %%
ies_capes = IES_df[['CO_IES', 'IN_ACESSO_PORTAL_CAPES']]
display(ies_capes)
# Out:
#       CO_IES  IN_ACESSO_PORTAL_CAPES
# 0          1                       1
# 1          2                       1
# 2          3                       1
# 3          4                       1
# 4          6                       1
# ...      ...                     ...
# 2532   23410                       0
# 2533     284                       0
# 2534     633                       1
# 2535    3311                       0
# 2536      74                       0
#
# [2537 rows x 2 columns]

# %%
#Medidas de 'qualidade' e acesso a bases científicas
ies_tec = IES_df[['QT_TEC_TOTAL', 'CO_IES']]
display(ies_tec)

ies_capes = IES_df['IN_ACESSO_PORTAL_CAPES'].value_counts()
display(ies_capes)

ies_outrabase = IES_df['IN_ASSINA_OUTRA_BASE'].value_counts()
display(ies_outrabase)

ies_repIn = IES_df['IN_REPOSITORIO_INSTITUCIONAL'].value_counts()
display(ies_repIn)

ies_busca = IES_df['IN_BUSCA_INTEGRADA'].value_counts()
display(ies_busca)

ies_internet = IES_df['IN_SERVICO_INTERNET'].value_counts()
display(ies_internet)

ies_catOn = IES_df['IN_CATALOGO_ONLINE'].value_counts()
display(ies_catOn)

ies_qtPer = IES_df['QT_PERIODICO_ELETRONICO'].value_counts()
display(ies_qtPer)

ies_qtLivro = IES_df['QT_LIVRO_ELETRONICO'].value_counts()
display(ies_qtLivro)
# Out:
# QT_TEC_TOTAL  CO_IES
# 14581         586       1
# 23            5473      1
#               1237      1
#               1456      1
#               1569      1
#                        ..
# 83            826       1
#               1936      1
#               3099      1
#               3613      1
# 1             1254      1
# Length: 2031, dtype: int64
# 0    1246
# 1     785
# Name: IN_ACESSO_PORTAL_CAPES, dtype: int64
# 1    1283
# 0     748
# Name: IN_ASSINA_OUTRA_BASE, dtype: int64
# 0    1127
# 1     904
# Name: IN_REPOSITORIO_INSTITUCIONAL, dtype: int64
# 0    1127
# 1     904
# Name: IN_REPOSITORIO_INSTITUCIONAL, dtype: int64
# 1    1451
# 0     580
# Name: IN_BUSCA_INTEGRADA, dtype: int64
# 1    1910
# 0     121
# Name: IN_SERVICO_INTERNET, dtype: int64
# 1    1603
# 0     428
# Name: IN_CATALOGO_ONLINE, dtype: int64
# 0        460
# 22813    103
# 22203     68
# 30000     44
# 1         32
#         ...
# 6500       1
# 357        1
# 358        1
# 35724      1
# ...
